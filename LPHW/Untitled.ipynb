# %%
import json
import itchat
itchat.login()
# Out:
# itchat has already logged in.

# %%
friends = itchat.get_friends(update=True)[0:]

# %%
print(len(friends[1:]))
# Out:
# 260

# %%
print(friends[1:])
# Out:
# [<User: {'RemarkPYInitial': '', 'ChatRoomId': 0, 'VerifyFlag': 0, 'City': '成都', 'Alias': '', 'MemberList': <ContactList: []>, 'AttrStatus': 110079, 'UserName': '@cf09104b23d3a212e5ffc426e47e3617', 'ContactFlag': 2051, 'OwnerUin': 0, 'Statues': 0, 'EncryChatRoomId': '', 'PYQuanPin': 'guxiaome', 'RemarkName': '', 'StarFriend': 0, 'Uin': 0, 'HideInputBarFlag': 0, 'AppAccountFlag': 0, 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=644897322&username=@cf09104b23d3a212e5ffc426e47e3617&skey=@crypt_ba60ae0_05e71f4c295f20715414bee396e0961d', 'MemberCount': 0, 'NickName': '骨小麽', 'RemarkPYQuanPin': '', 'UniFriend': 0, 'Province': '四川', 'Sex': 2, 'Signature': '好好做个没用的人', 'DisplayName': '', 'KeyWord': 'gux', 'IsOwner': 0, 'SnsFlag': 49, 'PYInitial': 'GXM'}>, <User: {'RemarkPYInitial': '', 'ChatRoomId': 0, 'VerifyFlag': 0, 'City': '东城', 'Alias': '', 'MemberList': <ContactList: []>, 'AttrStatus': 100541, 'UserName': '@a3c1ac80b766e75f1ada8b988d1cf26f32d64250b1900f56bf6e3b72117238f9', 'Contact
# ...
